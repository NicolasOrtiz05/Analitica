# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolasOrtiz05/Analitica/blob/main/Practica_1_snake_reactive_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 1: Ambiente Snake y Agente Reactivo
# ### Analítica de Datos
# ### Universidad de La Sabana
#
# ---
#
# **Fecha límite de entrega**: Miércoles 14 de agosto antes de la medianoche (ver instrucciones en Teams).
#
#
# Cerciórese de reiniciar y correr el notebook en su totalidad antes de enviarlo. Verifique que todas las salidas se muestran de manera correcta.
#
# Integrantes del grupo (máximo 3):
#
# * Nombre_1 username_1
# * Nombre_2 username_2
# * Nombre_3 username_3
#
# ---
#
# Las siguientes instrucciones instalan las librerías y archivos necesarios para el notebook. Si ejecuta el notebook en un entorno local, verifique las direcciones estén bien.

# %%
# !rm -r snake-ai-reinforcement # Elimina (rm: remove) cualquier cosa que se llame igual y que de casualidad tenga ud en la misma carpeta del notebook
# !git clone https://github.com/YuriyGuts/snake-ai-reinforcement.git # Clona el repositorio de github en cuestion (git clone)
# !mv snake-ai-reinforcement/snakeai . # Mueve (mv: move) la carpeta /snake al mismo directorio del notebook
# !ls # lista (ls: list) el contenido del directorio donde está el notebook
# Out:
# rm: cannot remove 'snake-ai-reinforcement': No such file or directory
# Cloning into 'snake-ai-reinforcement'...
# remote: Enumerating objects: 197, done.
# remote: Total 197 (delta 0), reused 0 (delta 0), pack-reused 197 (from 1)
# Receiving objects: 100% (197/197), 42.98 KiB | 8.59 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# sample_data  snakeai  snake-ai-reinforcement

# %% [markdown]
# Vamos a construir un agente que sea capaz de jugar el juego de *Snake*:
#
# <img src="https://cloud.githubusercontent.com/assets/2750531/24808769/cc825424-1bc5-11e7-816f-7320f7bda2cf.gif" alt="Snake snapshot" width="320"/>
#
# Para esto vamos a usar como base este [proyecto](https://github.com/YuriyGuts/snake-ai-reinforcement) desarrollado por [Yuriy Guts](https://github.com/YuriyGuts).
#
# Primero definimos una clase que nos permite simular el juego:

# %%
from snakeai.gameplay.environment import Environment

class EnvironmentPO(Environment):
    """
    Partial observation environment. Same as base class environment, overloads
    `get_observation` so that only the cells in front of the snake are returned.
    (From Environment doc): Represents the RL environment for the Snake game that implements the game logic,
    provides rewards for the agent and keeps track of game statistics.
    """
    def __init__(self, config, verbose=0):
        super().__init__(config, verbose)

    @property
    def observation_shape(self):
        """ Get the shape of the state observed at each timestep. """
        return 3

    def get_observation(self):
        """ Observe the state of the environment. """
        if self.is_game_over:
            return (0, 0, 0)
        center = self.snake.head + self.snake.direction
        if self.snake.direction == Point(0,1):
            left = self.snake.head + Point(1,0)
            right = self.snake.head + Point(-1, 0)
        elif self.snake.direction == Point(0, -1):
            left = self.snake.head + Point(-1, 0)
            right = self.snake.head + Point(1, 0)
        elif self.snake.direction == Point(1, 0):
            left = self.snake.head + Point(0, -1)
            right = self.snake.head + Point(0, 1)
        else:
            left = self.snake.head + Point(0, 1)
            right = self.snake.head + Point(0, -1)
        return (self.field[left], self.field[center], self.field[right])

    def show_field(self):
        return self.field.__str__()

# %% [markdown]
# Esta clase extiende la clase `Environment` del proyecto `snakeai`:
#
# ```Python
# class Environment(object):
#     """
#     Represents the RL environment for the Snake game that implements the game logic,
#     provides rewards for the agent and keeps track of game statistics.
#     """
#
#     def __init__(self, config, verbose=1):
#         """
#         Create a new Snake RL environment.
#
#         Args:
#             config (dict): level configuration, typically found in JSON configs.
#             verbose (int): verbosity level:
#                 0 = do not write any debug information;
#                 1 = write a CSV file containing the statistics for every episode;
#                 2 = same as 1, but also write a full log file containing the state of each timestep.
#         """
#         self.field = Field(level_map=config['field'])
#         self.snake = None
#         self.fruit = None
#         self.initial_snake_length = config['initial_snake_length']
#         self.rewards = config['rewards']
#         self.max_step_limit = config.get('max_step_limit', 1000)
#         self.is_game_over = False
#
#         self.timestep_index = 0
#         self.current_action = None
#         self.stats = EpisodeStatistics()
#         self.verbose = verbose
#         self.debug_file = None
#         self.stats_file = None
#
#     def seed(self, value):
#
#     @property
#     def observation_shape(self):
#         """ Get the shape of the state observed at each timestep. """
#
#     @property
#     def num_actions(self):
#         """ Get the number of actions the agent can take. """
#
#     def new_episode(self):
#         """ Reset the environment and begin a new episode. """
#
#     def record_timestep_stats(self, result):
#         """ Record environment statistics according to the verbosity level. """
#
#     def get_observation(self):
#         """ Observe the state of the environment. """
#
#     def choose_action(self, action):
#         """ Choose the action that will be taken at the next timestep. """
#
#     def timestep(self):
#         """ Execute the timestep and return the new observable state. """
#
#     def generate_fruit(self, position=None):
#         """ Generate a new fruit at a random unoccupied cell. """
#
#     def has_hit_wall(self):
#         """ True if the snake has hit a wall, False otherwise. """
#
#     def has_hit_own_body(self):
#         """ True if the snake has hit its own body, False otherwise. """
#
#     def is_alive(self):
#         """ True if the snake is still alive, False otherwise. """
# ```

# %% [markdown]
# Un agente para jugar Snake lo construimos extendiendo la clase `AgentBase`. El siguiente es un agente que ejecuta sus acciones al azar:

# %%
from snakeai.agent import AgentBase

class RandomActionAgent(AgentBase):
    """ Represents a Snake agent that takes a random action at every step. """

    def __init__(self):
        pass

    def begin_episode(self):
        pass

    def act(self, observation, reward):
        return random.choice(ALL_SNAKE_ACTIONS)

    def end_episode(self):
        pass

# %% [markdown]
# Finalmente definimos una función `play` que nos permite simular el juego:

# %%
from snakeai.gameplay.entities import ALL_SNAKE_ACTIONS, Point
import numpy as np
import random


def play(env, agent, num_episodes=1, verbose=1):
    """
    Play a set of episodes using the specified Snake agent.
    Use the non-interactive command-line interface and print the summary statistics afterwards.

    Args:
        env: an instance of Snake environment.
        agent: an instance of Snake agent.
        num_episodes (int): the number of episodes to run.
    """

    fruit_stats = []

    print()
    print('Playing:')

    for episode in range(num_episodes):
        timestep = env.new_episode()
        agent.begin_episode()
        game_over = False
        step = 0
        while not game_over:
            if verbose > 0:
                print("------ Step ", step, " ------")
                print (env.show_field())
                print ("Observation:", env.get_observation())
                print ("Head:", env.snake.head)
                print ("Direction:", env.snake.direction)
            step += 1
            action = agent.act(timestep.observation, timestep.reward)
            env.choose_action(action)
            timestep = env.timestep()
            game_over = timestep.is_episode_end

        fruit_stats.append(env.stats.fruits_eaten)

        summary = '******* Episode {:3d} / {:3d} | Timesteps {:4d} | Fruits {:2d}'
        print(summary.format(episode + 1, num_episodes, env.stats.timesteps_survived, env.stats.fruits_eaten))

    print()
    print('Fruits eaten {:.1f} +/- stddev {:.1f}'.format(np.mean(fruit_stats), np.std(fruit_stats)))

# %% [markdown]
# Ya tenemos todos los elementos necesarios para simular el juego. Arrancamos con un tablero inicial en el cual
# la serpiente está en el centro. Esto lo especificamos con un dictionario que indica la configuración, los campos
# que nos interesan son `field`, `initial_snake_length` y `max_step_limit`, los otros campo los podemo ignorar por el momento:

# %%
inicial = {
  "field": [
    "#######",
    "#.....#",
    "#.....#",
    "#..S..#",
    "#.....#",
    "#.....#",
    "#######"
  ],

  "initial_snake_length": 2,
  "max_step_limit": 100,

  "rewards": {
    "timestep": -0.01,
    "ate_fruit": 1,
    "died": -1
  }
}

# %% [markdown]
# Veamos como se comporta el agente aleatorio con esta configuración:

# %%
env = EnvironmentPO(config=inicial, verbose=0)
agent = RandomActionAgent()
play(env, agent, num_episodes= 100, verbose=1)

# %% [markdown]
# ## 1. Agente con un plan determinado
#
# Vamos a construir un agente que partiendo del siguiente estado inicial:

# %%
```
#######
#.....#
#.###.#
#..S..#
##.s..#
#.....#
#######
```

# %% [markdown]
# llegue al siguiente estado

# %%
```
#######
#.....#
#s###.#
#S....#
##....#
#.....#
#######
```

# %%
from snakeai.gameplay.entities import SnakeAction
class PredefinedActionAgent(AgentBase):
    """ Represents a Snake agent that takes a random action at every step. """

    def __init__(self, actions):
        self.actions = actions
        self.step = 0
        pass

    def begin_episode(self):
        pass

    def act(self, observation, reward):
        """
        The agent takes the next action in the list of actions. Increases
        step by 1.
        """

        if self.step < len(self.actions):
            action = self.actions[self.step]
            self.step += 1
        else:
            action = SnakeAction.MAINTAIN_DIRECTION


        # Your code here

        return action

    def end_episode(self):
        pass

# %%
from snakeai.gameplay.entities import SnakeAction
inicial1 = inicial = {
  "field": [
    "#######",
    "#.....#",
    "#.###.#",
    "#..S..#",
    "##.s..#",
    "#.....#",
    "#######"
  ],

  "initial_snake_length": 2,
  "max_step_limit": 1000,

  "rewards": {
    "timestep": -0.01,
    "ate_fruit": 1,
    "died": -1
  }
}

env = EnvironmentPO(config=inicial1, verbose=1)
agent = PredefinedActionAgent([
    SnakeAction.TURN_RIGHT,
    SnakeAction.MAINTAIN_DIRECTION,
    SnakeAction.TURN_LEFT,
    SnakeAction.MAINTAIN_DIRECTION,
    SnakeAction.TURN_LEFT,
    SnakeAction.MAINTAIN_DIRECTION,
    SnakeAction.MAINTAIN_DIRECTION,
    SnakeAction.MAINTAIN_DIRECTION,
    SnakeAction.TURN_LEFT,
    SnakeAction.MAINTAIN_DIRECTION
])
play(env, agent, num_episodes= 1, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-f48daa631b8b> in <cell line: 24>()
#      22
#      23 env = EnvironmentPO(config=inicial1, verbose=1)
# ---> 24 agent = PredefinedActionAgent([
#      25     SnakeAction.TURN_RIGHT,
#      26     SnakeAction.MAINTAIN_DIRECTION,
#
# NameError: name 'PredefinedActionAgent' is not defined

# %% [markdown]
# ## 2. Agente reactivo
#
# La idea es construir un agente reactivo, es decir que sus acciones solo dependen de la observación en un momento dado y
# no tiene memoria. El agente debe procurar no estrellarse y come cuantas frutas pueda. Compare el comportamiento de este agente con el del agente
# al azar. Simule cada agente por 100 episodios. Presente los resultados y discútalos.

# %%
from snakeai.agent import AgentBase
from snakeai.gameplay.entities import SnakeAction, CellType

class ReactiveAgent(AgentBase):
    """
    Represents a reactive Snake agent that dcides an action exclusively based on
    the current observation.
    """

    def __init__(self):
        pass

    def begin_episode(self):
        pass

    def act(self, observation, reward):
        """
        The agent anlizes de current observation and takes a consequent action.
        """
        # Your code here
        left, front, right = observation

        if front == CellType.FRUIT:
            return SnakeAction.MAINTAIN_DIRECTION
        elif left == CellType.FRUIT:
            return SnakeAction.TURN_LEFT
        elif right == CellType.FRUIT:
            return SnakeAction.TURN_RIGHT

        else:
            valid_actions = []
            if front not in (CellType.WALL, CellType.SNAKE_BODY):
                valid_actions.append(SnakeAction.MAINTAIN_DIRECTION)
            if left not in (CellType.WALL, CellType.SNAKE_BODY):
                valid_actions.append(SnakeAction.TURN_LEFT)
            if right not in (CellType.WALL, CellType.SNAKE_BODY):
                valid_actions.append(SnakeAction.TURN_RIGHT)

            if not valid_actions:
                valid_actions = ALL_SNAKE_ACTIONS

            return random.choice(valid_actions)
    def end_episode(self):
        pass

# %%
#Funcionamiento agente reactivo
from snakeai.gameplay.entities import SnakeAction
inicial2 = inicial = {
  "field": [
    "#######",
    "#.....#",
    "#.###.#",
    "#..S..#",
    "#..s..#",
    "#.....#",
    "#######"
  ],

  "initial_snake_length": 2,
  "max_step_limit": 100,

  "rewards": {
    "timestep": -0.01,
    "ate_fruit": 1,
    "died": -1
  }
}

env = EnvironmentPO(config=inicial2, verbose=1)
agent = ReactiveAgent()
play(env, agent, num_episodes= 2, verbose=1)
# Out:
# Playing:
# ------ Step  0  ------
# #######
# #.....#
# #.###.#
# #..S..#
# #.Os..#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  1  ------
# #######
# #.....#
# #.###.#
# #..sS.#
# #.O...#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  2  ------
# #######
# #.....#
# #.###.#
# #...s.#
# #.O.S.#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  3  ------
# #######
# #.....#
# #.###.#
# #.....#
# #.OSs.#
# #.....#
# #######
# Observation: (0, 1, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  4  ------
# #######
# #.....#
# #.###.#
# #O....#
# #.Sss.#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  5  ------
# #######
# #.....#
# #.###.#
# #OS...#
# #.ss..#
# #.....#
# #######
# Observation: (1, 4, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  6  ------
# #######
# #.....#
# #.###.#
# #Ss.O.#
# #.ss..#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=-1, y=0)
# ------ Step  7  ------
# #######
# #.....#
# #S###.#
# #ss.O.#
# #.s...#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  8  ------
# #######
# #S....#
# #s###.#
# #ss.O.#
# #.....#
# #.....#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  9  ------
# #######
# #sS...#
# #s###.#
# #s..O.#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=2, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  10  ------
# #######
# #ssS..#
# #s###.#
# #...O.#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=3, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  11  ------
# #######
# #sssS.#
# #.###.#
# #...O.#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=4, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  12  ------
# #######
# #.sssS#
# #.###.#
# #...O.#
# #.....#
# #.....#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=1)
# Direction: Point(x=1, y=0)
# ------ Step  13  ------
# #######
# #..sss#
# #.###S#
# #...O.#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  14  ------
# #######
# #...ss#
# #.###s#
# #...OS#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 1)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  15  ------
# #######
# #...ss#
# #.###s#
# #...Ss#
# #..O..#
# #.....#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=4, y=3)
# Direction: Point(x=-1, y=0)
# ------ Step  16  ------
# #######
# #....s#
# #.###s#
# #...ss#
# #..OS.#
# #.....#
# #######
# Observation: (0, 0, 1)
# Head: Point(x=4, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  17  ------
# #######
# #...Os#
# #.###s#
# #...ss#
# #..Ss.#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  18  ------
# #######
# #...O.#
# #.###s#
# #..Sss#
# #..ss.#
# #.....#
# #######
# Observation: (0, 4, 3)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  19  ------
# #######
# #...O.#
# #.###.#
# #.Ssss#
# #..ss.#
# #.....#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=2, y=3)
# Direction: Point(x=-1, y=0)
# ------ Step  20  ------
# #######
# #...O.#
# #.###.#
# #.sss.#
# #.Sss.#
# #.....#
# #######
# Observation: (3, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  21  ------
# #######
# #...O.#
# #.###.#
# #.ss..#
# #.sss.#
# #.S...#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  22  ------
# #######
# #...O.#
# #.###.#
# #.ss..#
# #.ss..#
# #.sS..#
# #######
# Observation: (3, 0, 4)
# Head: Point(x=3, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  23  ------
# #######
# #...O.#
# #.###.#
# #.ss..#
# #.s...#
# #.ssS.#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=4, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  24  ------
# #######
# #...O.#
# #.###.#
# #.s...#
# #.s...#
# #.sssS#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=5, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  25  ------
# #######
# #...O.#
# #.###.#
# #.....#
# #.s..S#
# #.ssss#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  26  ------
# #######
# #...O.#
# #.###.#
# #.....#
# #...Ss#
# #.ssss#
# #######
# Observation: (3, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  27  ------
# #######
# #...O.#
# #.###.#
# #...S.#
# #...ss#
# #..sss#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  28  ------
# #######
# #...O.#
# #.###.#
# #..Ss.#
# #...ss#
# #...ss#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=3, y=3)
# Direction: Point(x=-1, y=0)
# ------ Step  29  ------
# #######
# #...O.#
# #.###.#
# #..ss.#
# #..Sss#
# #....s#
# #######
# Observation: (3, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  30  ------
# #######
# #...O.#
# #.###.#
# #..ss.#
# #.Ssss#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  31  ------
# #######
# #...O.#
# #.###.#
# #..ss.#
# #Ssss.#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  32  ------
# #######
# #...O.#
# #.###.#
# #..ss.#
# #sss..#
# #S....#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  33  ------
# #######
# #...O.#
# #.###.#
# #..s..#
# #sss..#
# #sS...#
# #######
# Observation: (3, 0, 4)
# Head: Point(x=2, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  34  ------
# #######
# #...O.#
# #.###.#
# #.....#
# #sss..#
# #ssS..#
# #######
# Observation: (3, 0, 4)
# Head: Point(x=3, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  35  ------
# #######
# #...O.#
# #.###.#
# #.....#
# #ss...#
# #sssS.#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=4, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  36  ------
# #######
# #...O.#
# #.###.#
# #.....#
# #s....#
# #ssssS#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=5, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  37  ------
# #######
# #...O.#
# #.###.#
# #.....#
# #....S#
# #sssss#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  38  ------
# #######
# #...O.#
# #.###.#
# #....S#
# #....s#
# #.ssss#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=5, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  39  ------
# #######
# #...O.#
# #.###S#
# #....s#
# #....s#
# #..sss#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  40  ------
# #######
# #...OS#
# #.###s#
# #....s#
# #....s#
# #...ss#
# #######
# Observation: (1, 4, 4)
# Head: Point(x=5, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  41  ------
# #######
# #...Ss#
# #O###s#
# #....s#
# #....s#
# #...ss#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=4, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  42  ------
# #######
# #..Sss#
# #O###s#
# #....s#
# #....s#
# #....s#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=3, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  43  ------
# #######
# #.Ssss#
# #O###s#
# #....s#
# #....s#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=2, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  44  ------
# #######
# #Sssss#
# #O###s#
# #....s#
# #.....#
# #.....#
# #######
# Observation: (1, 4, 4)
# Head: Point(x=1, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  45  ------
# #######
# #sssss#
# #S###s#
# #....s#
# #.O...#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  46  ------
# #######
# #sssss#
# #s###s#
# #S....#
# #.O...#
# #.....#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  47  ------
# #######
# #sssss#
# #s###.#
# #sS...#
# #.O...#
# #.....#
# #######
# Observation: (4, 0, 1)
# Head: Point(x=2, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  48  ------
# #######
# #sssss#
# #s###.#
# #ss...#
# #.S..O#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  49  ------
# #######
# #ssss.#
# #s###.#
# #ss...#
# #Ss..O#
# #.....#
# #######
# Observation: (0, 4, 3)
# Head: Point(x=1, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  50  ------
# #######
# #sss..#
# #s###.#
# #ss...#
# #ss..O#
# #S....#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  51  ------
# #######
# #ss...#
# #s###.#
# #ss...#
# #ss..O#
# #sS...#
# #######
# Observation: (3, 0, 4)
# Head: Point(x=2, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  52  ------
# #######
# #s....#
# #s###.#
# #ss...#
# #ss..O#
# #ssS..#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=3, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  53  ------
# #######
# #.....#
# #s###.#
# #ss...#
# #ssS.O#
# #sss..#
# #######
# Observation: (3, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  54  ------
# #######
# #.....#
# #.###.#
# #ss...#
# #sssSO#
# #sss..#
# #######
# Observation: (0, 1, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=1, y=0)
# ------ Step  55  ------
# #######
# #.....#
# #.###.#
# #ss.O.#
# #ssssS#
# #sss..#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=5, y=4)
# Direction: Point(x=1, y=0)
# ------ Step  56  ------
# #######
# #.....#
# #.###.#
# #.s.O.#
# #sssss#
# #sss.S#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=5, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  57  ------
# #######
# #.....#
# #.###.#
# #...O.#
# #sssss#
# #sssSs#
# #######
# Observation: (4, 3, 3)
# Head: Point(x=4, y=5)
# Direction: Point(x=-1, y=0)
# ******* Episode   1 /   2 | Timesteps   58 | Fruits  8
# ------ Step  0  ------
# #######
# #O....#
# #.###.#
# #..S..#
# #..s..#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  1  ------
# #######
# #O....#
# #.###.#
# #..sS.#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  2  ------
# #######
# #O....#
# #.###.#
# #...s.#
# #...S.#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  3  ------
# #######
# #O....#
# #.###.#
# #.....#
# #...s.#
# #...S.#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  4  ------
# #######
# #O....#
# #.###.#
# #.....#
# #.....#
# #..Ss.#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  5  ------
# #######
# #O....#
# #.###.#
# #.....#
# #.....#
# #.Ss..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  6  ------
# #######
# #O....#
# #.###.#
# #.....#
# #.S...#
# #.s...#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  7  ------
# #######
# #O....#
# #.###.#
# #.....#
# #.sS..#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=1, y=0)
# ------ Step  8  ------
# #######
# #O....#
# #.###.#
# #.....#
# #..sS.#
# #.....#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=1, y=0)
# ------ Step  9  ------
# #######
# #O....#
# #.###.#
# #.....#
# #...s.#
# #...S.#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  10  ------
# #######
# #O....#
# #.###.#
# #.....#
# #.....#
# #..Ss.#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  11  ------
# #######
# #O....#
# #.###.#
# #.....#
# #.....#
# #.Ss..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  12  ------
# #######
# #O....#
# #.###.#
# #.....#
# #.....#
# #Ss...#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  13  ------
# #######
# #O....#
# #.###.#
# #.....#
# #S....#
# #s....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  14  ------
# #######
# #O....#
# #.###.#
# #S....#
# #s....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  15  ------
# #######
# #O....#
# #.###.#
# #sS...#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  16  ------
# #######
# #O....#
# #.###.#
# #.sS..#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  17  ------
# #######
# #O....#
# #.###.#
# #..sS.#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  18  ------
# #######
# #O....#
# #.###.#
# #...sS#
# #.....#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  19  ------
# #######
# #O....#
# #.###S#
# #....s#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  20  ------
# #######
# #O...S#
# #.###s#
# #.....#
# #.....#
# #.....#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=5, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  21  ------
# #######
# #O..Ss#
# #.###.#
# #.....#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=4, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  22  ------
# #######
# #O.Ss.#
# #.###.#
# #.....#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=3, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  23  ------
# #######
# #OSs..#
# #.###.#
# #.....#
# #.....#
# #.....#
# #######
# Observation: (4, 1, 4)
# Head: Point(x=2, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  24  ------
# #######
# #Sss..#
# #.###.#
# #.....#
# #.....#
# #.O...#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  25  ------
# #######
# #ss...#
# #S###.#
# #.....#
# #.....#
# #.O...#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  26  ------
# #######
# #s....#
# #s###.#
# #S....#
# #.....#
# #.O...#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  27  ------
# #######
# #.....#
# #s###.#
# #sS...#
# #.....#
# #.O...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  28  ------
# #######
# #.....#
# #.###.#
# #ssS..#
# #.....#
# #.O...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  29  ------
# #######
# #.....#
# #.###.#
# #.ssS.#
# #.....#
# #.O...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  30  ------
# #######
# #.....#
# #.###.#
# #..ss.#
# #...S.#
# #.O...#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  31  ------
# #######
# #.....#
# #.###.#
# #...s.#
# #...s.#
# #.O.S.#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  32  ------
# #######
# #.....#
# #.###.#
# #.....#
# #...s.#
# #.O.sS#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=5, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  33  ------
# #######
# #.....#
# #.###.#
# #.....#
# #....S#
# #.O.ss#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  34  ------
# #######
# #.....#
# #.###.#
# #.....#
# #...Ss#
# #.O..s#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  35  ------
# #######
# #.....#
# #.###.#
# #.....#
# #...ss#
# #.O.S.#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=4, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  36  ------
# #######
# #.....#
# #.###.#
# #.....#
# #...s.#
# #.OSs.#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=3, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  37  ------
# #######
# #.....#
# #.###.#
# #...O.#
# #...s.#
# #.Sss.#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  38  ------
# #######
# #.....#
# #.###.#
# #...O.#
# #.S...#
# #.sss.#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  39  ------
# #######
# #.....#
# #.###.#
# #.S.O.#
# #.s...#
# #.ss..#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  40  ------
# #######
# #.....#
# #.###.#
# #.sSO.#
# #.s...#
# #.s...#
# #######
# Observation: (4, 1, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  41  ------
# #######
# #..O..#
# #.###.#
# #.ssS.#
# #.s...#
# #.s...#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  42  ------
# #######
# #..O..#
# #.###.#
# #.sssS#
# #.s...#
# #.....#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  43  ------
# #######
# #..O..#
# #.###S#
# #.ssss#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  44  ------
# #######
# #..O.S#
# #.###s#
# #..sss#
# #.....#
# #.....#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=5, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  45  ------
# #######
# #..OSs#
# #.###s#
# #...ss#
# #.....#
# #.....#
# #######
# Observation: (4, 1, 4)
# Head: Point(x=4, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  46  ------
# #######
# #.OSss#
# #.###s#
# #...ss#
# #.....#
# #.....#
# #######
# Observation: (4, 1, 4)
# Head: Point(x=3, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  47  ------
# #######
# #.Ssss#
# #.###s#
# #...ss#
# #.....#
# #.O...#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=2, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  48  ------
# #######
# #Sssss#
# #.###s#
# #....s#
# #.....#
# #.O...#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  49  ------
# #######
# #sssss#
# #S###s#
# #.....#
# #.....#
# #.O...#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  50  ------
# #######
# #sssss#
# #s###.#
# #S....#
# #.....#
# #.O...#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  51  ------
# #######
# #ssss.#
# #s###.#
# #s....#
# #S....#
# #.O...#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  52  ------
# #######
# #sss..#
# #s###.#
# #s....#
# #s....#
# #SO...#
# #######
# Observation: (1, 4, 4)
# Head: Point(x=1, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  53  ------
# #######
# #sss..#
# #s###.#
# #s..O.#
# #s....#
# #sS...#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=2, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  54  ------
# #######
# #ss...#
# #s###.#
# #s..O.#
# #s....#
# #ssS..#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=3, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  55  ------
# #######
# #s....#
# #s###.#
# #s..O.#
# #s.S..#
# #sss..#
# #######
# Observation: (0, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  56  ------
# #######
# #.....#
# #s###.#
# #s..O.#
# #sSs..#
# #sss..#
# #######
# Observation: (3, 3, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  57  ------
# #######
# #.....#
# #.###.#
# #sS.O.#
# #sss..#
# #sss..#
# #######
# Observation: (3, 4, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  58  ------
# #######
# #.....#
# #.###.#
# #.sSO.#
# #sss..#
# #sss..#
# #######
# Observation: (4, 1, 3)
# Head: Point(x=3, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  59  ------
# #######
# #.....#
# #.###.#
# #OssS.#
# #sss..#
# #sss..#
# #######
# Observation: (4, 0, 0)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  60  ------
# #######
# #.....#
# #.###.#
# #OsssS#
# #.ss..#
# #sss..#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=5, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  61  ------
# #######
# #.....#
# #.###S#
# #Ossss#
# #.ss..#
# #.ss..#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  62  ------
# #######
# #....S#
# #.###s#
# #Ossss#
# #.ss..#
# #..s..#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=5, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  63  ------
# #######
# #...Ss#
# #.###s#
# #Ossss#
# #.ss..#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=4, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  64  ------
# #######
# #..Sss#
# #.###s#
# #Ossss#
# #.s...#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=3, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  65  ------
# #######
# #.Ssss#
# #.###s#
# #Ossss#
# #.....#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=2, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  66  ------
# #######
# #Sssss#
# #.###s#
# #O.sss#
# #.....#
# #.....#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  67  ------
# #######
# #sssss#
# #S###s#
# #O..ss#
# #.....#
# #.....#
# #######
# Observation: (4, 1, 4)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  68  ------
# #######
# #sssss#
# #s###s#
# #S..ss#
# #....O#
# #.....#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  69  ------
# #######
# #sssss#
# #s###s#
# #s...s#
# #S...O#
# #.....#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  70  ------
# #######
# #sssss#
# #s###s#
# #s....#
# #s...O#
# #S....#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  71  ------
# #######
# #sssss#
# #s###.#
# #s....#
# #s...O#
# #sS...#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=2, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  72  ------
# #######
# #ssss.#
# #s###.#
# #s....#
# #s...O#
# #ssS..#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=3, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  73  ------
# #######
# #sss..#
# #s###.#
# #s....#
# #s...O#
# #sssS.#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=4, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  74  ------
# #######
# #ss...#
# #s###.#
# #s....#
# #s...O#
# #ssssS#
# #######
# Observation: (1, 4, 4)
# Head: Point(x=5, y=5)
# Direction: Point(x=1, y=0)
# ------ Step  75  ------
# #######
# #ss..O#
# #s###.#
# #s....#
# #s...S#
# #sssss#
# #######
# Observation: (0, 0, 4)
# Head: Point(x=5, y=4)
# Direction: Point(x=0, y=-1)
# ------ Step  76  ------
# #######
# #s...O#
# #s###.#
# #s....#
# #s..Ss#
# #sssss#
# #######
# Observation: (3, 0, 0)
# Head: Point(x=4, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  77  ------
# #######
# #....O#
# #s###.#
# #s....#
# #s.Sss#
# #sssss#
# #######
# Observation: (3, 0, 0)
# Head: Point(x=3, y=4)
# Direction: Point(x=-1, y=0)
# ------ Step  78  ------
# #######
# #....O#
# #.###.#
# #s.S..#
# #s.sss#
# #sssss#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=3, y=3)
# Direction: Point(x=0, y=-1)
# ------ Step  79  ------
# #######
# #....O#
# #.###.#
# #..sS.#
# #s.sss#
# #sssss#
# #######
# Observation: (4, 0, 3)
# Head: Point(x=4, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  80  ------
# #######
# #....O#
# #.###.#
# #..ssS#
# #..sss#
# #sssss#
# #######
# Observation: (0, 4, 3)
# Head: Point(x=5, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  81  ------
# #######
# #....O#
# #.###S#
# #..sss#
# #..sss#
# #.ssss#
# #######
# Observation: (4, 1, 4)
# Head: Point(x=5, y=2)
# Direction: Point(x=0, y=-1)
# ------ Step  82  ------
# #######
# #...OS#
# #.###s#
# #..sss#
# #..sss#
# #.ssss#
# #######
# Observation: (1, 4, 4)
# Head: Point(x=5, y=1)
# Direction: Point(x=0, y=-1)
# ------ Step  83  ------
# #######
# #...Ss#
# #.###s#
# #.Osss#
# #..sss#
# #.ssss#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=4, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  84  ------
# #######
# #..Sss#
# #.###s#
# #.Osss#
# #..sss#
# #..sss#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=3, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  85  ------
# #######
# #.Ssss#
# #.###s#
# #.Osss#
# #..sss#
# #...ss#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=2, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  86  ------
# #######
# #Sssss#
# #.###s#
# #.Osss#
# #..sss#
# #....s#
# #######
# Observation: (0, 4, 4)
# Head: Point(x=1, y=1)
# Direction: Point(x=-1, y=0)
# ------ Step  87  ------
# #######
# #sssss#
# #S###s#
# #.Osss#
# #..sss#
# #.....#
# #######
# Observation: (4, 0, 4)
# Head: Point(x=1, y=2)
# Direction: Point(x=0, y=1)
# ------ Step  88  ------
# #######
# #sssss#
# #s###s#
# #SOsss#
# #..ss.#
# #.....#
# #######
# Observation: (1, 0, 4)
# Head: Point(x=1, y=3)
# Direction: Point(x=0, y=1)
# ------ Step  89  ------
# #######
# #sssss#
# #s###s#
# #sSsss#
# #..ss.#
# #...O.#
# #######
# Observation: (4, 3, 0)
# Head: Point(x=2, y=3)
# Direction: Point(x=1, y=0)
# ------ Step  90  ------
# #######
# #sssss#
# #s###s#
# #sssss#
# #.Ss..#
# #...O.#
# #######
# Observation: (3, 0, 0)
# Head: Point(x=2, y=4)
# Direction: Point(x=0, y=1)
# ------ Step  91  ------
# #######
# #sssss#
# #s###s#
# #sssss#
# #.s...#
# #.S.O.#
# #######
# Observation: (0, 4, 0)
# Head: Point(x=2, y=5)
# Direction: Point(x=0, y=1)
# ------ Step  92  ------
# #######
# #sssss#
# #s###s#
# #ss.ss#
# #.s...#
# #Ss.O.#
# #######
# Observation: (4, 4, 0)
# Head: Point(x=1, y=5)
# Direction: Point(x=-1, y=0)
# ------ Step  93  ------
# #######
# #sssss#
# #s###s#
# #ss..s#
# #Ss...#
# #ss.O.#
# #######
# Observation: (4, 3, 3)
# Head: Point(x=1, y=4)
# Direction: Point(x=0, y=-1)
# ******* Episode   2 /   2 | Timesteps   94 | Fruits 12
#
# Fruits eaten 10.0 +/- stddev 2.0

# %% [markdown]
# Ahora con una nueva funcion podemos comparar cuantas frutas come el agente

# %%
from snakeai.gameplay.entities import Point
import numpy as np
import random

def play_com(env, agent_random, agent_reactivo, num_episodes=100, verbose=1):
    fruit_stats_random = []
    fruit_stats_reactivo = []

    print()
    print('Playing:')

    for episode in range(num_episodes):
        # Agente aleatorio
        env.new_episode()
        agent_random.begin_episode()
        game_over = False
        while not game_over:
            observation = env.get_observation()
            action = agent_random.act(observation, 0)
            env.choose_action(action)
            timestep = env.timestep()
            game_over = timestep.is_episode_end

        fruit_stats_random.append(env.stats.fruits_eaten)

        # Agente reactivo
        env.new_episode()
        agent_reactivo.begin_episode()
        game_over = False
        while not game_over:
            observation = env.get_observation()
            action = agent_reactivo.act(observation, 0)
            env.choose_action(action)
            timestep = env.timestep()
            game_over = timestep.is_episode_end

        fruit_stats_reactivo.append(env.stats.fruits_eaten)

        if verbose:
            summary = '******* Episode {:3d} / {:3d} | Timesteps {:4d} | Fruits Random {:2d} | Fruits Reactivo {:2d}'
            print(summary.format(episode + 1, num_episodes, env.stats.timesteps_survived,
                                 fruit_stats_random[-1], fruit_stats_reactivo[-1]))

    if verbose:
        print()
        print('Average fruits eaten by Random Agent: {:.1f} +/- stddev {:.1f}'.format(
            np.mean(fruit_stats_random), np.std(fruit_stats_random)))
        print('Average fruits eaten by Reactive Agent: {:.1f} +/- stddev {:.1f}'.format(
            np.mean(fruit_stats_reactivo), np.std(fruit_stats_reactivo)))

# %%
from snakeai.gameplay.entities import SnakeAction
inicial3 = {
  "field": [
    "#######",
    "#.....#",
    "#.###.#",
    "#..S..#",
    "#..s..#",
    "#.....#",
    "#######"
  ],

  "initial_snake_length": 2,
  "max_step_limit": 100,

  "rewards": {
    "timestep": -0.01,
    "ate_fruit": 1,
    "died": -1
  }
}

env = EnvironmentPO(config=inicial2, verbose=1)
agent_reactivo = ReactiveAgent()
agent_random = RandomActionAgent()
play_com(env, agent_random, agent_reactivo, num_episodes=100, verbose=1)
# Out:
# Playing:
# ******* Episode   1 / 100 | Timesteps   41 | Fruits Random  0 | Fruits Reactivo  4
# ******* Episode   2 / 100 | Timesteps   73 | Fruits Random  0 | Fruits Reactivo 15
# ******* Episode   3 / 100 | Timesteps   41 | Fruits Random  1 | Fruits Reactivo  5
# ******* Episode   4 / 100 | Timesteps   38 | Fruits Random  0 | Fruits Reactivo  7
# ******* Episode   5 / 100 | Timesteps   66 | Fruits Random  0 | Fruits Reactivo  9
# ******* Episode   6 / 100 | Timesteps   56 | Fruits Random  0 | Fruits Reactivo 10
# ******* Episode   7 / 100 | Timesteps   81 | Fruits Random  0 | Fruits Reactivo  6
# ******* Episode   8 / 100 | Timesteps   74 | Fruits Random  0 | Fruits Reactivo  9
# ******* Episode   9 / 100 | Timesteps  100 | Fruits Random  1 | Fruits Reactivo  6
# ******* Episode  10 / 100 | Timesteps   39 | Fruits Random  0 | Fruits Reactivo  5
# ******* Episode  11 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo  0
# ******* Episode  12 / 100 | Timesteps   88 | Fruits Random  0 | Fruits Reactivo  8
# ******* Episode  13 / 100 | Timesteps   80 | Fruits Random  0 | Fruits Reactivo  8
# ******* Episode  14 / 100 | Timesteps   55 | Fruits Random  0 | Fruits Reactivo  7
# ******* Episode  15 / 100 | Timesteps   86 | Fruits Random  0 | Fruits Reactivo 10
# ******* Episode  16 / 100 | Timesteps   87 | Fruits Random  0 | Fruits Reactivo  8
# ******* Episode  17 / 100 | Timesteps   75 | Fruits Random  0 | Fruits Reactivo 14
# ******* Episode  18 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo 10
# ******* Episode  19 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo  3
# ******* Episode  20 / 100 | Timesteps   38 | Fruits Random  0 | Fruits Reactivo  8
# ******* Episode  21 / 100 | Timesteps  100 | Fruits Random  1 | Fruits Reactivo  8
# ******* Episode  22 / 100 | Timesteps   93 | Fruits Random  0 | Fruits Reactivo 10
# ******* Episode  23 / 100 | Timesteps   49 | Fruits Random  0 | Fruits Reactivo  6
# ******* Episode  24 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo  5
# ******* Episode  25 / 100 | Timesteps   81 | Fruits Random  0 | Fruits Reactivo 14
# ******* Episode  26 / 100 | Timesteps   66 | Fruits Random  0 | Fruits Reactivo 12
# ******* Episode  27 / 100 | Timesteps   93 | Fruits Random  0 | Fruits Reactivo 16
# ******* Episode  28 / 100 | Timesteps   71 | Fruits Random  0 | Fruits Reactivo  5
# ******* Episode  29 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo  6
# ******* Episode  30 / 100 | Timesteps   53 | Fruits Random  0 | Fruits Reactivo  4
# ******* Episode  31 / 100 | Timesteps   79 | Fruits Random  0 | Fruits Reactivo 10
# ******* Episode  32 / 100 | Timesteps   21 | Fruits Random  0 | Fruits Reactivo  4
# ******* Episode  33 / 100 | Timesteps   78 | Fruits Random  0 | Fruits Reactivo  7
# ******* Episode  34 / 100 | Timesteps   56 | Fruits Random  0 | Fruits Reactivo 12
# ******* Episode  35 / 100 | Timesteps   67 | Fruits Random  0 | Fruits Reactivo  6
# ******* Episode  36 / 100 | Timesteps   61 | Fruits Random  0 | Fruits Reactivo  4
# ******* Episode  37 / 100 | Timesteps   72 | Fruits Random  0 | Fruits Reactivo 11
# ******* Episode  38 / 100 | Timesteps   33 | Fruits Random  0 | Fruits Reactivo  5
# ******* Episode  39 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo  8
# ******* Episode  40 / 100 | Timesteps   43 | Fruits Random  0 | Fruits Reactivo  5
# ******* Episode  41 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo  8
# ******* Episode  42 / 100 | Timesteps   49 | Fruits Random  0 | Fruits Reactivo  6
# ******* Episode  43 / 100 | Timesteps   71 | Fruits Random  1 | Fruits Reactivo 12
# ******* Episode  44 / 100 | Timesteps   84 | Fruits Random  1 | Fruits Reactivo  7
# ******* Episode  45 / 100 | Timesteps   83 | Fruits Random  0 | Fruits Reactivo 12
# ******* Episode  46 / 100 | Timesteps   95 | Fruits Random  0 | Fruits Reactivo  6
# ******* Episode  47 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo 12
# ******* Episode  48 / 100 | Timesteps   73 | Fruits Random  0 | Fruits Reactivo  8
# ******* Episode  49 / 100 | Timesteps   79 | Fruits Random  0 | Fruits Reactivo  5
# ******* Episode  50 / 100 | Timesteps   96 | Fruits Random  0 | Fruits Reactivo  7
# ******* Episode  51 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo  3
# ******* Episode  52 / 100 | Timesteps  100 | Fruits Random  1 | Fruits Reactivo  7
# ******* Episode  53 / 100 | Timesteps   15 | Fruits Random  0 | Fruits Reactivo  2
# ******* Episode  54 / 100 | Timesteps   22 | Fruits Random  0 | Fruits Reactivo  5
# ******* Episode  55 / 100 | Timesteps  100 | Fruits Random  0 | Fruits Reactivo 10
# ******* Episode  56 / 100 | Timesteps  100 | Fruits Random  1 | Fruits Reactivo  6
# ******* Episode  57 / 100 | Timesteps   23 | Fruits Random  0 | Fruits Reactivo  3
# ******* Episode  58 / 100 | Timesteps   79 | Fruits Random  0 | Fruits Reactivo 11
# ******* Episode  59 / 100 | Timesteps   98 | Fruits Random  0 | Fruits Reactivo 12
# ******* Episode  60 / 100 | Timesteps   15 | Fruits Random  0 | Fruits Reactivo  3
# ******* Episode  61 / 100 | Timesteps   49 | Fruits Random  0 | Fruits Reactivo  2
# ******* Episode  62 / 100 | Timesteps   89 | Fruits Random  0 | Fruits Reactivo 10
# ******* Episode  63 / 100 | Timesteps  100 | Fruits Random  1 | Fruits Reactivo  9
# ******* Episode  64 / 100 | Timesteps   63 | Fruits Random  0 | Fruits Reactivo  8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-88c146d07098> in <cell line: 26>()
#      24 agent_reactivo = ReactiveAgent()
#      25 agent_random = RandomActionAgent()
# ---> 26 play_com(env, agent_random, agent_reactivo, num_episodes=100, verbose=1)
#
# <ipython-input-52-bfa5ec8e77a3> in play_com(env, agent_random, agent_reactivo, num_episodes, verbose)
#      32             action = agent_reactivo.act(observation, 0)
#      33             env.choose_action(action)
# ---> 34             timestep = env.timestep()
#      35             game_over = timestep.is_episode_end
#      36
#
# /content/snakeai/gameplay/environment.py in timestep(self)
#     130         if self.snake.peek_next_move() == self.fruit:
#     131             self.snake.grow()
# --> 132             self.generate_fruit()
#     133             old_tail = None
#     134             reward += self.rewards['ate_fruit'] * self.snake.length
#
# /content/snakeai/gameplay/environment.py in generate_fruit(self, position)
#     170         """ Generate a new fruit at a random unoccupied cell. """
#     171         if position is None:
# --> 172             position = self.field.get_random_empty_cell()
#     173         self.field[position] = CellType.FRUIT
#     174         self.fruit = position
#
# /content/snakeai/gameplay/entities.py in get_random_empty_cell(self)
#     197     def get_random_empty_cell(self):
#     198         """ Get the coordinates of a random empty cell. """
# --> 199         return random.choice(list(self._empty_cells))
#     200
#     201     def place_snake(self, snake):
#
# /usr/lib/python3.10/random.py in choice(self, seq)
#     376         """Choose a random element from a non-empty sequence."""
#     377         # raises IndexError if seq is empty
# --> 378         return seq[self._randbelow(len(seq))]
#     379
#     380     def shuffle(self, x, random=None):
#
# IndexError: list index out of range
